# %%
# !pip install soccerplots

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from soccerplots.radar_chart import Radar

# %%
data = pd.read_csv(r'C:\Users\Bankole Temitope\Desktop\PLSTATS.txt', sep=',')
print (data)
data.to_csv(r'C:\Users\Bankole Temitope\Desktop\PLSTATS.csv', index=False)
# Out:
#       Rk               Player   Nation   Pos         Squad     Age  Born  MP  \
# 0      1     Brenden Aaronson   us USA  MFFW  Leeds United  22-204  2000  34
# 1      2            Che Adams  sct SCO    FW   Southampton  26-305  1996  28
# 2      3          Tyler Adams   us USA    MF  Leeds United  24-089  1999  24
# 3      4     Tosin Adarabioyo  eng ENG    DF        Fulham  25-232  1997  23
# 4      5         Nayef Aguerd   ma MAR    DF      West Ham  27-045  1996  16
# ..   ...                  ...      ...   ...           ...     ...   ...  ..
# 553  554        Jordan Zemura   zw ZIM    DF   Bournemouth  23-181  1999  19
# 554  555  Oleksandr Zinchenko   ua UKR    DF       Arsenal  26-150  1996  27
# 555  556         Hakim Ziyech   ma MAR  FWMF       Chelsea  30-056  1993  17
# 556  557           Kurt Zouma   fr FRA    DF      West Ham  28-199  1994  24
# 557  558      Martin Ødegaard   no NOR    MF       Arsenal  24-148  1998  34
#
# ...

# %%
stats = pd.read_csv(r'C:\Users\Bankole Temitope\Desktop\PLSTATS.csv')
stats
# Out:
#       Rk               Player   Nation   Pos         Squad     Age  Born  MP  \
# 0      1     Brenden Aaronson   us USA  MFFW  Leeds United  22-204  2000  34
# 1      2            Che Adams  sct SCO    FW   Southampton  26-305  1996  28
# 2      3          Tyler Adams   us USA    MF  Leeds United  24-089  1999  24
# 3      4     Tosin Adarabioyo  eng ENG    DF        Fulham  25-232  1997  23
# 4      5         Nayef Aguerd   ma MAR    DF      West Ham  27-045  1996  16
# ..   ...                  ...      ...   ...           ...     ...   ...  ..
# 553  554        Jordan Zemura   zw ZIM    DF   Bournemouth  23-181  1999  19
# 554  555  Oleksandr Zinchenko   ua UKR    DF       Arsenal  26-150  1996  27
# 555  556         Hakim Ziyech   ma MAR  FWMF       Chelsea  30-056  1993  17
# 556  557           Kurt Zouma   fr FRA    DF      West Ham  28-199  1994  24
# 557  558      Martin Ødegaard   no NOR    MF       Arsenal  24-148  1998  34
#
# ...

# %%
stats.Player.unique()
# Out:
# array(['Brenden Aaronson', 'Che Adams', 'Tyler Adams', 'Tosin Adarabioyo',
#        'Nayef Aguerd', 'Naouirou Ahamada', 'Rayan Aït Nouri',
#        'Kristoffer Ajer', 'Manuel Akanji', 'Nathan Aké',
#        'Marc Albrighton', 'Thiago Alcántara', 'Carlos Alcaraz',
#        'Trent Alexander-Arnold', 'Alisson', 'Dele Alli', 'Miguel Almirón',
#        'Julián Álvarez', 'Daniel Amartey', 'Joachim Andersen',
#        'Elliot Anderson', 'Jaidon Anthony', 'Michail Antonio', 'Antony',
#        'Cameron Archer', 'Alphonse Areola', 'Joe Aribo', 'Adam Armstrong',
#        'Stuart Armstrong', 'Kepa Arrizabalaga',
#        'Pierre-Emerick Aubameyang', 'Ludwig Augustinsson', 'Serge Aurier',
#        'Taiwo Awoniyi', 'Yasin Ayari', 'André Ayew', 'Jordan Ayew',
#        'Luke Ayling', 'César Azpilicueta', 'Benoît Badiashile',
#        'Leon Bailey', 'Stefan Bajcetic', 'Patrick Bamford',
#        'Shandon Baptiste', 'Harvey Barnes', 'Gavin Bazunu',
# ...

# %%
S = stats[(stats['Player'] == 'Marcus Rashford') | (stats['Player'] == 'Martinelli')]
S
# Out:
#       Rk           Player   Nation Pos           Squad     Age  Born  MP  \
# 318  319       Martinelli   br BRA  FW         Arsenal  21-330  2001  35
# 411  412  Marcus Rashford  eng ENG  FW  Manchester Utd  25-195  1997  33
#
#      Starts   Min  ...  G+A.1  G-PK.1  G+A-PK  xG.1  xAG.1  xG+xAG  npxG.1  \
# 318      33  2770  ...   0.65    0.49    0.65  0.30    0.3    0.60    0.30
# 411      31  2741  ...   0.69    0.53    0.69  0.45    0.1    0.55    0.45
#
#      npxG+xAG.1  Matches     -9999
# 318        0.60  Matches  48a5a5d6
# 411        0.55  Matches  a1d5bd30
#
# [2 rows x 38 columns]

# %%
S.columns
# Out:
# Index(['Rk', 'Player', 'Nation', 'Pos', 'Squad', 'Age', 'Born', 'MP', 'Starts',
#        'Min', '90s', 'Gls', 'Ast', 'G+A', 'G-PK', 'PK', 'PKatt', 'CrdY',
#        'CrdR', 'xG', 'npxG', 'xAG', 'npxG+xAG', 'PrgC', 'PrgP', 'PrgR',
#        'Gls.1', 'Ast.1', 'G+A.1', 'G-PK.1', 'G+A-PK', 'xG.1', 'xAG.1',
#        'xG+xAG', 'npxG.1', 'npxG+xAG.1', 'Matches', '-9999'],
#       dtype='object')

# %%
S = S.rename(columns={
    "Pos":"Position",
    "Gls": "Goals",
    "Ast": "Assists",
    "G+A": "Goals + Assists",
    "G-PK": "Non Penalty Goals",
    "G+A-PK": "Non Penalty Goals + Assists per 90",
    "PK" : "Penalty",
    "xG": "Expected Goals",
    "xAG": "Expected Assists",
    "npxG": "Non Penalty Expected Goals",
    "npxG+xAG": "Non Penalty Expected Goals+Expected Assists",
    "PrgC": "Progressive Carries",
    "PrgP" : "Progressive Passes",
    "PrgR" : "Progresive Passes Recieved",
    "Gls.1": "Goals Per 90",
    "Ast.1": "Assists per 90",
    "G+A.1": "Goals + Assists per 90",
    "G-PK.1" : "Non Penalty Goals per 90",
    "xG.1" : "Expected Goals per 90",
    "xAG.1": "Expected Assists per 90",
    "xG+xAG": "Expected Goals + Expected Assists per 90",
    "npxG.1": "Non Penalty Expected Goals per 90",
    "npxG+xAG.1": "Non Penalty Expected Goals+Expected Assists per 90",
})
S
# Out:
#       Rk           Player   Nation Position           Squad     Age  Born  MP  \
# 318  319       Martinelli   br BRA       FW         Arsenal  21-330  2001  35
# 411  412  Marcus Rashford  eng ENG       FW  Manchester Utd  25-195  1997  33
#
#      Starts   Min  ...  Goals + Assists per 90  Non Penalty Goals per 90  \
# 318      33  2770  ...                    0.65                      0.49
# 411      31  2741  ...                    0.69                      0.53
#
#      Non Penalty Goals + Assists per 90  Expected Goals per 90  \
# 318                                0.65                   0.30
# 411                                0.69                   0.45
#
#      Expected Assists per 90  Expected Goals + Expected Assists per 90  \
# 318                      0.3                                      0.60
# 411                      0.1                                      0.55
#
#      Non Penalty Expected Goals per 90  \
# 318                               0.30
# ...

# %%
col_names = S.columns.to_list()
col_names
# Out:
# ['Rk',
#  'Player',
#  'Nation',
#  'Position',
#  'Squad',
#  'Age',
#  'Born',
#  'MP',
#  'Starts',
#  'Min',
#  '90s',
#  'Goals',
#  'Assists',
#  'Goals + Assists',
#  'Non Penalty Goals',
#  'Penalty',
#  'PKatt',
#  'CrdY',
#  'CrdR',
#  'Expected Goals',
#  'Non Penalty Expected Goals',
#  'Expected Assists',
#  'Non Penalty Expected Goals+Expected Assists',
#  'Progressive Carries',
#  'Progressive Passes',
#  'Progresive Passes Recieved',
#  'Goals Per 90',
#  'Assists per 90',
#  'Goals + Assists per 90',
#  'Non Penalty Goals per 90',
#  'Non Penalty Goals + Assists per 90',
#  'Expected Goals per 90',
#  'Expected Assists per 90',
#  'Expected Goals + Expected Assists per 90',
#  'Non Penalty Expected Goals per 90',
#  'Non Penalty Expected Goals+Expected Assists per 90',
#  'Matches',
#  '-9999']

# %%
S = S[['Rk',
 'Player',
 'Goals',
 'Non Penalty Goals',
 'Assists',
 'Goals + Assists',
 'Expected Goals',
 'Expected Assists',
 'Progressive Carries',
 'Progressive Passes',
 'Progresive Passes Recieved',
#  'Goals Per 90',
#  'Assists per 90',
 'Goals + Assists per 90',
#  'Non Penalty Goals per 90',
#  'Non Penalty Goals + Assists per 90',
#  'Expected Goals per 90',
#  'Expected Assists per 90',
#  'Expected Goals + Expected Assists per 90',
#  'Non Penalty Expected Goals per 90',
 'Non Penalty Expected Goals+Expected Assists per 90'
]]
S
# Out:
#       Rk           Player  Goals  Non Penalty Goals  Assists  Goals + Assists  \
# 318  319       Martinelli     15                 15        5               20
# 411  412  Marcus Rashford     16                 16        5               21
#
#      Expected Goals  Expected Assists  Progressive Carries  \
# 318             9.3               9.1                  124
# 411            13.6               3.1                   77
#
#      Progressive Passes  Progresive Passes Recieved  Goals + Assists per 90  \
# 318                  94                         350                    0.65
# 411                  77                         233                    0.69
#
#      Non Penalty Expected Goals+Expected Assists per 90
# 318                                               0.60
# 411                                               0.55

# %%
col_names = S.columns.to_list()
col_names
# Out:
# ['Rk',
#  'Player',
#  'Goals',
#  'Non Penalty Goals',
#  'Assists',
#  'Goals + Assists',
#  'Expected Goals',
#  'Expected Assists',
#  'Progressive Carries',
#  'Progressive Passes',
#  'Progresive Passes Recieved',
#  'Goals + Assists per 90',
#  'Non Penalty Expected Goals+Expected Assists per 90']

# %%
c = col_names[2:]
c
# Out:
# ['Goals',
#  'Non Penalty Goals',
#  'Assists',
#  'Goals + Assists',
#  'Expected Goals',
#  'Expected Assists',
#  'Progressive Carries',
#  'Progressive Passes',
#  'Progresive Passes Recieved',
#  'Goals + Assists per 90',
#  'Non Penalty Expected Goals+Expected Assists per 90']

# %%
R = []
for colnames in col_names[2:]:
    Min = min(S[colnames])
    Max = max(S[colnames])
    R.append((Min - 0.2 * Min, Max + 0.2 * Max))
R
# Out:
# [(12.0, 19.2),
#  (12.0, 19.2),
#  (4.0, 6.0),
#  (16.0, 25.2),
#  (7.44, 16.32),
#  (2.48, 10.92),
#  (61.6, 148.8),
#  (61.6, 112.8),
#  (186.4, 420.0),
#  (0.52, 0.828),
#  (0.44000000000000006, 0.72)]

# %%
S
# Out:
#       Rk           Player  Goals  Non Penalty Goals  Assists  Goals + Assists  \
# 318  319       Martinelli     15                 15        5               20
# 411  412  Marcus Rashford     16                 16        5               21
#
#      Expected Goals  Expected Assists  Progressive Carries  \
# 318             9.3               9.1                  124
# 411            13.6               3.1                   77
#
#      Progressive Passes  Progresive Passes Recieved  Goals + Assists per 90  \
# 318                  94                         350                    0.65
# 411                  77                         233                    0.69
#
#      Non Penalty Expected Goals+Expected Assists per 90
# 318                                               0.60
# 411                                               0.55

# %%
S1 = []
for i in range(len(S)):
    S1.append(S.iloc[i, 2:].tolist())

print(S1)
# Out:
# [[15, 15, 5, 20, 9.3, 9.1, 124, 94, 350, 0.65, 0.6], [16, 16, 5, 21, 13.6, 3.1, 77, 77, 233, 0.69, 0.55]]

# %%
T = dict(
    title_name = 'Martinelli',
    title_color = 'blue',
    subtitle_name = 'Lw, Arsenal',
    subtitle_color = 'blue',
    title_name_2 = 'Rashford',
    title_color_2 = 'red',
    subtitle_name_2 = 'Lw, Manchester United',
    subtitle_color_2 = 'red'
)
T
# Out:
# {'title_name': 'Martinelli',
#  'title_color': 'blue',
#  'subtitle_name': 'Lw, Arsenal',
#  'subtitle_color': 'blue',
#  'title_name_2': 'Rashford',
#  'title_color_2': 'red',
#  'subtitle_name_2': 'Lw, Manchester United',
#  'subtitle_color_2': 'red'}

# %%
note = 'Bankole Temitope \nFBREF data'

# %%
radar = Radar(background_color="black", patch_color="#28252C", label_color="white", range_color="#BFE9BF")
fig, ax = radar.plot_radar(ranges = R, params = c, values = S1, alphas = [0.76, 0.6], 
                           title = T, endnote = note, radar_color=['#0f4c75', '#e94560'], compare=True)
